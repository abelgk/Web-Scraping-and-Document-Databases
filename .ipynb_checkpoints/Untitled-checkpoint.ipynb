# %%
# Dependencies
import pymongo
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
executable_path = {'executable_path': 'chromedriver.exe'}
browser = Browser('chrome',**executable_path, headless=False)

# %%
# URL of page to be scraped
url = 'https://mars.nasa.gov/news/'
browser.visit(url)
html = browser.html

# Create BeautifulSoup object; parse with 'html'
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-27-e10b8f94331e> in <module>()
#       2 url = 'https://mars.nasa.gov/news/'
#       3 browser.visit(url)
# ----> 4 html = browser.html
#       5
#       6 # Create BeautifulSoup object; parse with 'html'
#
# ~\Anaconda3\lib\site-packages\splinter\driver\webdriver\__init__.py in html(self)
#     183     @property
#     184     def html(self):
# --> 185         return self.driver.page_source
#     186
#     187     @property
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=71.0.3578.98)
#   (Driver info: chromedriver=2.45.615291 (ec3682e3c9061c10f26ea9e5cdcf3c53f3f74387),platform=Windows NT 10.0.17134 x86_64)

# %%
# Retrieve the parent divs for all articles
results = soup.find_all('li', class_='slide')
# Loop through results to retrieve article title and paragraph
for result in results:
    div = result.find('div',class_='content_title')
    link = div.find('a')
    news_title = link.text.strip()
    paragraph = result.find('div',class_='article_teaser_body')
    news_p = paragraph.text.strip()
    print(f'News Title:{news_title}')
    print(f'News Article:{news_p}')
    print("====================")
# Out:
# News Title:NASA's InSight Places First Instrument on Mars
# News Article:In deploying its first instrument onto the surface of Mars, the lander completes a major mission milestone.
# ====================
# News Title:InSight Engineers Have Made a Martian Rock Garden
# News Article:Reconstructing Mars here on Earth lets them practice setting down the lander's science instruments.
# ====================
# News Title:Mars InSight Lander Seen in First Images from Space
# News Article:Look closely, and you can make out the lander's solar panels.
# ====================
# News Title:NASA's InSight Takes Its First Selfie
# News Article:Two new image mosaics detail the lander's deck and "workspace" — the surface where it will eventually set down its science instruments.
# ====================
# News Title:NASA InSight Lander 'Hears' Martian Winds
# News Article:Vibrations picked up by two spacecraft instruments have provided the first sounds of Martian wind.
# ====================
# News Title:NASA's Mars InSight Flexes Its Arm
# News Article:Now unstowed, the spacecraft's robotic arm will point a camera located on its elbow and take images of the surroundings.
# ====================
# News Title:Mars New Home 'a Large Sandbox'
# News Article:With InSight safely on the surface of Mars, the mission team is busy learning more about the spacecraft's landing site.
# ====================
# News Title:NASA Hears MarCO CubeSats Loud and Clear from Mars
# News Article:A pair of tiny, experimental spacecraft fulfilled their mission yesterday, relaying back near-real-time data during InSight's landing.
# ====================
# News Title:InSight Is Catching Rays on Mars
# News Article:The lander has sent data indicating its solar panels are open and receiving sunlight to power its surface operations.
# ====================
# News Title:NASA InSight Lander Arrives on Martian Surface
# News Article:The touchdown marks the eighth time NASA has successfully landed a spacecraft on Mars.
# ====================
# News Title:Landing Day for InSight
# News Article:NASA's InSight spacecraft is on target for Mars landing at around noon PST today.
# ====================
# News Title:NASA InSight Landing on Mars: Milestones
# News Article:On Nov. 26, NASA's InSight spacecraft will blaze through the Martian atmosphere and set a lander gently on the surface in less time than it takes to cook a hard-boiled egg.
# ====================
# News Title:NASA InSight Team on Course for Mars Touchdown
# News Article:NASA's Mars InSight spacecraft is on track for a soft touchdown on the surface of the Red Planet on Nov. 26.
# ====================
# News Title:What Two Planetary Siblings Can Teach Us About Life
# News Article:In studying Mars, NASA's InSight will reveal what makes one planet more or less suitable for life than another.
# ====================
# News Title:NASA Announces Landing Site for Mars 2020 Rover
# News Article:After a five-year search, NASA has chosen Jezero Crater as the landing site for its upcoming Mars 2020 rover mission.
# ====================
# News Title:NASA to Host Media Call on Next Mars Landing Site
# News Article:NASA will host a media teleconference at 9 a.m. PST (noon EST) Monday, Nov. 19, to provide details about the Mars 2020 rover’s landing site on the Red Planet.
# ====================
# News Title:How NASA Will Know When InSight Touches Down
# News Article:On Nov. 26, engineers will look for a combination of signals to determine whether the next spacecraft to Mars lands safely.
# ====================
# News Title:NASA Brings Mars Landing to Viewers Everywhere
# News Article:NASA's InSight lander is scheduled to touch down on the Red Planet at approximately noon PST  on Nov. 26, with a new suite of instruments to probe below the Martian surface.
# ====================
# News Title:Curiosity on the Move Again
# News Article:NASA's Mars Curiosity rover drove about 197 feet over the weekend to a site called Lake Orcadie, pushing its total odometry to over 12 miles.
# ====================
# News Title:The Mars InSight Landing Site Is Just Plain Perfect
# News Article:If the InSight landing zone were ice cream, it would be vanilla.
# ====================
# News Title:Five Things to Know About InSight's Mars Landing
# News Article:NASA engineers will be holding their breath when their spacecraft heads into Mars' atmosphere on Nov. 26.
# ====================
# News Title:NASA Launches a New Podcast to Mars
# News Article:NASA's new eight-episode series 'On a Mission' follows the InSight spacecraft on its journey to Mars and details the extraordinary challenges of landing on the Red Planet.
# ====================
# News Title:Update on Opportunity Rover Recovery Efforts
# News Article:After a review of the progress of the listening campaign, NASA will continue its current strategy for attempting to make contact with the Opportunity rover for the foreseeable future.
# ====================
# News Title:Third ASPIRE Test Confirms Mars 2020 Parachute a Go
# News Article:The supersonic parachute that will handle the heaviest payload yet to the Red Planet – Mars 2020 rover – passes its final sounding rocket test with flying colors.
# ====================
# News Title:NASA to Host Briefing on November Mars InSight Landing
# News Article:A briefing on NASA's upcoming InSight Mars landing will air on Wed. Oct. 31 at 1:30 p.m. EDT (10:30 a.m. PDT) on NASA TV, the agency's website and NASA InSight Facebook Page.
# ====================
# News Title:NASA's InSight Will Study Mars While Standing Still
# News Article:The lander's unique science can teach us how planets are born.
# ====================
# News Title:NASA's First Image of Mars from a CubeSat
# News Article:The image was produced by one of the twin briefcase-sized MarCO spacecraft, the first CubeSats to fly to deep space.
# ====================
# News Title:The 'Claw Game' on Mars: NASA InSight Plays to Win
# News Article:NASA's InSight lander will be the first mission to use a robotic arm to grasp instruments from the spacecraft and place them on the surface of another planet.
# ====================
# News Title:Scientists to Debate Landing Site for Next Mars Rover
# News Article:Hundreds of scientists and Mars-exploration enthusiasts gather this week to present, discuss and deliberate the future landing site for NASA's next Red Planet.
# ====================
# News Title:Mars Virtual Reality Software Wins NASA Award
# News Article:A mixed-reality software that allows scientists and engineers to virtually walk on Mars has received NASA's 2018 Software of the Year Award.
# ====================
# News Title:Painting Cars for Mars
# News Article:What does NASA do to get a rover ready for Mars? JPL's paint shop does a thousand different paint jobs a year. And while every piece of spacecraft that comes through the shop is important, one headed for the Red Planet adds a little extra oomph.
# ====================
# News Title:Opportunity Emerges in a Dusty Picture
# News Article:NASA still hasn't heard from the Opportunity rover, but at least the agency can see it again.
# ====================
# News Title:NASA Seeking Partner in Contest to Name Next Mars Rover
# News Article:NASA has a class assignment for corporations, nonprofits and educational organizations involved in science and space exploration: partner with the agency to inspire future engineers and scientists by sponsoring a contest to name the next rover to venture to the Red Planet.
# ====================
# News Title:NASA's MAVEN Selfie Marks Four Years in Orbit at Mars
# News Article:NASA’s MAVEN spacecraft celebrates four years in Mars orbit with a selfie.
# ====================
# News Title:MarCO Makes Space for Small Explorers
# News Article:A pair of NASA CubeSats flying to Mars are opening a new frontier for small spacecraft.
# ====================
# News Title:Curiosity Surveys a Mystery Under Dusty Skies
# News Article:NASA's Curiosity rover surveyed its surroundings on Mars, producing a 360-degree panorama of its current location on Vera Rubin Ridge.
# ====================
# News Title:NASA's InSight Has a Thermometer for Mars
# News Article:The mission's heat probe could reveal how the planet's towering volcanoes formed.
# ====================
# News Title:Digital Creators: Apply for NASA Mars Landing Event
# News Article:Up to 30 multimedia participants will be selected for a special two-day event at JPL culminating in the InSight spacecraft's landing on Mars. Apply by Sept. 3.
# ====================
# News Title:NASA's InSight Passes Halfway to Mars, Instruments Check In
# News Article:NASA's InSight spacecraft, en route to a Nov. 26 landing on Mars, passed the halfway mark on Aug. 6. All of its instruments have been tested and are working well.
# ====================
# News Title:Six Things About Opportunity's Recovery Efforts
# News Article:The global dust storm on Mars could soon let in enough sunlight for the Opportunity rover to recharge.
# ====================

# %%
#Scrape JPL Mars images
jpl_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(jpl_url)

# %%
jpl_html = browser.html
jpl_soup = BeautifulSoup(html, 'html.parser')
articles = soup.find('ul', class_='articles')
images = articles.find_all('li', class_='slide')
image
